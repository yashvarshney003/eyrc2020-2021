# %%
import cv2 as cv
import numpy as np 
from matplotlib import pyplot as plt
import imutils

# %%
image = cv.imread("maze00.jpg",1)
orig = image.copy()

# %%
cv.imshow("image",image)
ratio = image.shape[0] / 500.0

# %%
image
# Out:
# array([[[107, 113, 112],
#         [108, 114, 113],
#         [109, 115, 114],
#         ...,
#         [117, 124, 127],
#         [116, 123, 126],
#         [117, 124, 127]],
#
#        [[111, 117, 116],
#         [111, 117, 116],
#         [111, 117, 116],
#         ...,
#         [118, 125, 128],
#         [117, 124, 127],
#         [117, 124, 127]],
#
#        [[112, 118, 117],
#         [111, 117, 116],
#         [111, 117, 116],
#         ...,
#         [119, 126, 129],
#         [118, 125, 128],
#         [118, 125, 128]],
#
#        ...,
#
#        [[117, 121, 132],
#         [121, 125, 136],
#         [125, 129, 140],
#         ...,
#         [180, 180, 192],
#         [182, 182, 194],
#         [184, 184, 196]],
#
#        [[120, 124, 135],
#         [125, 129, 140],
#         [127, 131, 142],
#         ...,
#         [184, 184, 196],
#         [186, 186, 198],
#         [188, 188, 200]],
#
#        [[125, 129, 140],
#         [130, 134, 145],
#         [131, 135, 146],
#         ...,
#         [178, 178, 190],
#         [180, 180, 192],
#         [182, 182, 194]]], dtype=uint8)

# %%
plt.imshow(image)
plt.show()

# %%
gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)

# %%
gray = cv.GaussianBlur(gray, (3,3), 2)
plt.imshow(gray)
imgplot1 = plt.imshow(gray, cmap='gray')

# %%
edged = cv.Canny(gray, 30, 200)

plt.imshow(edged)
imgplot = plt.imshow(edged, cmap='gray')

# %%
cnts = cv.findContours(edged.copy(), cv.RETR_LIST, cv.CHAIN_APPROX_SIMPLE)
cnts
# Out:
# ([array([[[355,  61]],
#
#          [[356,  60]],
#
#          [[357,  61]],
#
#          ...,
#
#          [[264,  62]],
#
#          [[298,  62]],
#
#          [[299,  61]]], dtype=int32),
#   array([[[356,  60]],
#
#          [[355,  61]],
#
#          [[299,  61]],
#
#          ...,
#
#          [[372,  60]],
#
#          [[358,  60]],
#
#          [[357,  61]]], dtype=int32),
#   array([[[353,  57]],
#
#          [[354,  56]],
#
#          [[452,  56]],
#
#          [[454,  58]],
#
#          [[454,  63]],
#
#          [[455,  64]],
#
#          [[455,  82]],
#
#          [[456,  83]],
#
#          [[456, 102]],
#
#          [[457, 103]],
#
#          [[457, 124]],
#
#          [[458, 125]],
#
#          [[458, 151]],
#
#          [[459, 152]],
#
#          [[459, 176]],
#
#          [[460, 177]],
#
#          [[460, 200]],
#
#          [[461, 201]],
#
#          [[461, 228]],
#
#          [[462, 229]],
#
#          [[462, 263]],
#
#          [[463, 264]],
#
#          [[463, 296]],
#
#          [[464, 297]],
#
#          [[464, 327]],
#
#          [[465, 328]],
#
#          [[465, 360]],
#
#          [[466, 361]],
#
#          [[466, 404]],
#
#          [[467, 405]],
#
#          [[467, 448]],
#
#          [[466, 449]],
#
#          [[464, 449]],
#
#          [[463, 450]],
#
#          [[439, 450]],
#
#          [[438, 451]],
#
#          [[409, 451]],
#
#          [[408, 452]],
#
#          [[374, 452]],
#
#          [[373, 453]],
#
#          [[336, 453]],
#
#          [[335, 454]],
#
#          [[296, 454]],
#
#          [[295, 455]],
#
#          [[261, 455]],
#
#          [[260, 456]],
#
#          [[212, 456]],
#
#          [[211, 457]],
#
#          [[ 71, 457]],
#
#          [[ 70, 456]],
#
#          [[ 69, 456]],
#
#          [[ 68, 455]],
#
#          [[ 68, 437]],
#
#          [[ 67, 436]],
#
#          [[ 67, 389]],
#
#          [[ 66, 388]],
#
#          [[ 66, 384]],
#
#          [[ 67, 383]],
#
#          [[ 66, 382]],
#
#          [[ 66, 318]],
#
#          [[ 65, 317]],
#
#          [[ 66, 316]],
#
#          [[ 66, 315]],
#
#          [[ 65, 314]],
#
#          [[ 65, 313]],
#
#          [[ 66, 312]],
#
#          [[ 66, 311]],
#
#          [[ 65, 310]],
#
#          [[ 65, 203]],
#
#          [[ 64, 202]],
#
#          [[ 64,  65]],
#
#          [[ 65,  64]],
#
#          [[ 66,  64]],
#
#          [[ 67,  63]],
#
#          [[ 87,  63]],
#
#          [[ 88,  62]],
#
#          [[116,  62]],
#
#          [[117,  61]],
#
#          [[150,  61]],
#
#          [[151,  60]],
#
#          [[195,  60]],
#
#          [[196,  59]],
#
#          [[248,  59]],
#
#          [[249,  58]],
#
#          [[296,  58]],
#
#          [[297,  57]]], dtype=int32),
#   array([[[354,  56]],
#
#          [[353,  57]],
#
#          [[297,  57]],
#
#          [[296,  58]],
#
#          [[249,  58]],
#
#          [[248,  59]],
#
#          [[196,  59]],
#
#          [[195,  60]],
#
#          [[151,  60]],
#
#          [[150,  61]],
#
#          [[117,  61]],
#
#          [[116,  62]],
#
#          [[ 88,  62]],
#
#          [[ 87,  63]],
#
#          [[ 67,  63]],
#
#          [[ 66,  64]],
#
#          [[ 64,  64]],
#
#          [[ 64, 202]],
#
#          [[ 65, 203]],
#
#          [[ 65, 310]],
#
#          [[ 66, 311]],
#
#          [[ 66, 312]],
#
#          [[ 65, 313]],
#
#          [[ 65, 314]],
#
#          [[ 66, 315]],
#
#          [[ 66, 316]],
#
#          [[ 65, 317]],
#
#          [[ 66, 318]],
#
#          [[ 66, 382]],
#
#          [[ 67, 383]],
#
#          [[ 66, 384]],
#
#          [[ 66, 388]],
#
#          [[ 67, 389]],
#
#          [[ 67, 436]],
#
#          [[ 68, 437]],
#
#          [[ 68, 456]],
#
#          [[ 70, 456]],
#
#          [[ 71, 457]],
#
#          [[211, 457]],
#
#          [[212, 456]],
#
#          [[260, 456]],
#
#          [[261, 455]],
#
#          [[295, 455]],
#
#          [[296, 454]],
#
#          [[335, 454]],
#
#          [[336, 453]],
#
#          [[373, 453]],
#
#          [[374, 452]],
#
#          [[408, 452]],
#
#          [[409, 451]],
#
#          [[438, 451]],
#
#          [[439, 450]],
#
#          [[463, 450]],
#
#          [[464, 449]],
#
#          [[467, 449]],
#
#          [[467, 405]],
#
#          [[466, 404]],
#
#          [[466, 361]],
#
#          [[465, 360]],
#
#          [[465, 328]],
#
#          [[464, 327]],
#
#          [[464, 297]],
#
#          [[463, 296]],
#
#          [[463, 264]],
#
#          [[462, 263]],
#
#          [[462, 229]],
#
#          [[461, 228]],
#
#          [[461, 201]],
#
#          [[460, 200]],
#
#          [[460, 177]],
#
#          [[459, 176]],
#
#          [[459, 152]],
#
#          [[458, 151]],
#
#          [[458, 125]],
#
#          [[457, 124]],
#
#          [[457, 103]],
#
#          [[456, 102]],
#
#          [[456,  83]],
#
#          [[455,  82]],
#
#          [[455,  64]],
#
#          [[454,  63]],
#
#          [[454,  57]],
#
#          [[453,  56]]], dtype=int32)],
#  array([[[ 1, -1, -1, -1],
#          [ 2,  0, -1, -1],
#          [ 3,  1, -1, -1],
#          [-1,  2, -1, -1]]], dtype=int32))

# %%
cnts = imutils.grab_contours(cnts)
cnts
# Out:
# [array([[[355,  61]],
#
#         [[356,  60]],
#
#         [[357,  61]],
#
#         ...,
#
#         [[264,  62]],
#
#         [[298,  62]],
#
#         [[299,  61]]], dtype=int32),
#  array([[[356,  60]],
#
#         [[355,  61]],
#
#         [[299,  61]],
#
#         ...,
#
#         [[372,  60]],
#
#         [[358,  60]],
#
#         [[357,  61]]], dtype=int32),
#  array([[[353,  57]],
#
#         [[354,  56]],
#
#         [[452,  56]],
#
#         [[454,  58]],
#
#         [[454,  63]],
#
#         [[455,  64]],
#
#         [[455,  82]],
#
#         [[456,  83]],
#
#         [[456, 102]],
#
#         [[457, 103]],
#
#         [[457, 124]],
#
#         [[458, 125]],
#
#         [[458, 151]],
#
#         [[459, 152]],
#
#         [[459, 176]],
#
#         [[460, 177]],
#
#         [[460, 200]],
#
#         [[461, 201]],
#
#         [[461, 228]],
#
#         [[462, 229]],
#
#         [[462, 263]],
#
#         [[463, 264]],
#
#         [[463, 296]],
#
#         [[464, 297]],
#
#         [[464, 327]],
#
#         [[465, 328]],
#
#         [[465, 360]],
#
#         [[466, 361]],
#
#         [[466, 404]],
#
#         [[467, 405]],
#
#         [[467, 448]],
#
#         [[466, 449]],
#
#         [[464, 449]],
#
#         [[463, 450]],
#
#         [[439, 450]],
#
#         [[438, 451]],
#
#         [[409, 451]],
#
#         [[408, 452]],
#
#         [[374, 452]],
#
#         [[373, 453]],
#
#         [[336, 453]],
#
#         [[335, 454]],
#
#         [[296, 454]],
#
#         [[295, 455]],
#
#         [[261, 455]],
#
#         [[260, 456]],
#
#         [[212, 456]],
#
#         [[211, 457]],
#
#         [[ 71, 457]],
#
#         [[ 70, 456]],
#
#         [[ 69, 456]],
#
#         [[ 68, 455]],
#
#         [[ 68, 437]],
#
#         [[ 67, 436]],
#
#         [[ 67, 389]],
#
#         [[ 66, 388]],
#
#         [[ 66, 384]],
#
#         [[ 67, 383]],
#
#         [[ 66, 382]],
#
#         [[ 66, 318]],
#
#         [[ 65, 317]],
#
#         [[ 66, 316]],
#
#         [[ 66, 315]],
#
#         [[ 65, 314]],
#
#         [[ 65, 313]],
#
#         [[ 66, 312]],
#
#         [[ 66, 311]],
#
#         [[ 65, 310]],
#
#         [[ 65, 203]],
#
#         [[ 64, 202]],
#
#         [[ 64,  65]],
#
#         [[ 65,  64]],
#
#         [[ 66,  64]],
#
#         [[ 67,  63]],
#
#         [[ 87,  63]],
#
#         [[ 88,  62]],
#
#         [[116,  62]],
#
#         [[117,  61]],
#
#         [[150,  61]],
#
#         [[151,  60]],
#
#         [[195,  60]],
#
#         [[196,  59]],
#
#         [[248,  59]],
#
#         [[249,  58]],
#
#         [[296,  58]],
#
#         [[297,  57]]], dtype=int32),
#  array([[[354,  56]],
#
#         [[353,  57]],
#
#         [[297,  57]],
#
#         [[296,  58]],
#
#         [[249,  58]],
#
#         [[248,  59]],
#
#         [[196,  59]],
#
#         [[195,  60]],
#
#         [[151,  60]],
#
#         [[150,  61]],
#
#         [[117,  61]],
#
#         [[116,  62]],
#
#         [[ 88,  62]],
#
#         [[ 87,  63]],
#
#         [[ 67,  63]],
#
#         [[ 66,  64]],
#
#         [[ 64,  64]],
#
#         [[ 64, 202]],
#
#         [[ 65, 203]],
#
#         [[ 65, 310]],
#
#         [[ 66, 311]],
#
#         [[ 66, 312]],
#
#         [[ 65, 313]],
#
#         [[ 65, 314]],
#
#         [[ 66, 315]],
#
#         [[ 66, 316]],
#
#         [[ 65, 317]],
#
#         [[ 66, 318]],
#
#         [[ 66, 382]],
#
#         [[ 67, 383]],
#
#         [[ 66, 384]],
#
#         [[ 66, 388]],
#
#         [[ 67, 389]],
#
#         [[ 67, 436]],
#
#         [[ 68, 437]],
#
#         [[ 68, 456]],
#
#         [[ 70, 456]],
#
#         [[ 71, 457]],
#
#         [[211, 457]],
#
#         [[212, 456]],
#
#         [[260, 456]],
#
#         [[261, 455]],
#
#         [[295, 455]],
#
#         [[296, 454]],
#
#         [[335, 454]],
#
#         [[336, 453]],
#
#         [[373, 453]],
#
#         [[374, 452]],
#
#         [[408, 452]],
#
#         [[409, 451]],
#
#         [[438, 451]],
#
#         [[439, 450]],
#
#         [[463, 450]],
#
#         [[464, 449]],
#
#         [[467, 449]],
#
#         [[467, 405]],
#
#         [[466, 404]],
#
#         [[466, 361]],
#
#         [[465, 360]],
#
#         [[465, 328]],
#
#         [[464, 327]],
#
#         [[464, 297]],
#
#         [[463, 296]],
#
#         [[463, 264]],
#
#         [[462, 263]],
#
#         [[462, 229]],
#
#         [[461, 228]],
#
#         [[461, 201]],
#
#         [[460, 200]],
#
#         [[460, 177]],
#
#         [[459, 176]],
#
#         [[459, 152]],
#
#         [[458, 151]],
#
#         [[458, 125]],
#
#         [[457, 124]],
#
#         [[457, 103]],
#
#         [[456, 102]],
#
#         [[456,  83]],
#
#         [[455,  82]],
#
#         [[455,  64]],
#
#         [[454,  63]],
#
#         [[454,  57]],
#
#         [[453,  56]]], dtype=int32)]

# %%
cnts = sorted(cnts, key = cv.contourArea, reverse = True)
# loop over the contours

	# show the contour (outline) of the piece of paper

# %%
len1 = len(cnts)
len1
# Out:
# 4

# %%
for c in cnts:
# approximate the contour
    peri = cv.arcLength(c, True)
    approx = cv.approxPolyDP(c, 0.02 * peri, True)
    print(len(approx))
# if our approximated contour has four points, then we
# can assume that we have found our screen
    if len(approx) == 4:
        screenCnt = approx
        break
# Out:
# 4

# %%
print("STEP 2: Find contours of paper")
print(screenCnt)
cv.drawContours(image, [screenCnt], -1, (0, 255, 0), 2)
# Out:
# STEP 2: Find contours of paper
# [[[453  56]]
#
#  [[ 64  64]]
#
#  [[ 68 456]]
#
#  [[467 449]]]
# array([[[107, 113, 112],
#         [108, 114, 113],
#         [109, 115, 114],
#         ...,
#         [117, 124, 127],
#         [116, 123, 126],
#         [117, 124, 127]],
#
#        [[111, 117, 116],
#         [111, 117, 116],
#         [111, 117, 116],
#         ...,
#         [118, 125, 128],
#         [117, 124, 127],
#         [117, 124, 127]],
#
#        [[112, 118, 117],
#         [111, 117, 116],
#         [111, 117, 116],
#         ...,
#         [119, 126, 129],
#         [118, 125, 128],
#         [118, 125, 128]],
#
#        ...,
#
#        [[117, 121, 132],
#         [121, 125, 136],
#         [125, 129, 140],
#         ...,
#         [180, 180, 192],
#         [182, 182, 194],
#         [184, 184, 196]],
#
#        [[120, 124, 135],
#         [125, 129, 140],
#         [127, 131, 142],
#         ...,
#         [184, 184, 196],
#         [186, 186, 198],
#         [188, 188, 200]],
#
#        [[125, 129, 140],
#         [130, 134, 145],
#         [131, 135, 146],
#         ...,
#         [178, 178, 190],
#         [180, 180, 192],
#         [182, 182, 194]]], dtype=uint8)

# %%
plt.imshow(image)
plt.show()

# %%
pts = screenCnt.reshape(4, 2)
print(pts)
# Out:
# [[453  56]
#  [ 64  64]
#  [ 68 456]
#  [467 449]]

# %%
rect = np.zeros((4, 2), dtype = "float32")
# the top-left point will have the smallest sum, whereas
# the bottom-right point will have the largest sum
s = pts.sum(axis = 1)
rect[0] = pts[np.argmin(s)]
rect[2] = pts[np.argmax(s)]
# now, compute the difference between the points, the
# top-right point will have the smallest difference,
# whereas the bottom-left will have the largest difference
diff = np.diff(pts, axis = 1)
rect[1] = pts[np.argmin(diff)]
rect[3] = pts[np.argmax(diff)]
# return the ordered coordinates
print(rect)
# Out:
# [[ 64.  64.]
#  [453.  56.]
#  [467. 449.]
#  [ 68. 456.]]

# %%
(tl, tr, br, bl) = rect
# compute the width of the new image, which will be the
# maximum distance between bottom-right and bottom-left
# x-coordiates or the top-right and top-left x-coordinates
widthA = np.sqrt(((br[0] - bl[0]) ** 2) + ((br[1] - bl[1]) ** 2))
widthB = np.sqrt(((tr[0] - tl[0]) ** 2) + ((tr[1] - tl[1]) ** 2))
maxWidth = max(int(widthA), int(widthB))
# compute the height of the new image, which will be the
# maximum distance between the top-right and bottom-right
# y-coordinates or the top-left and bottom-left y-coordinates
heightA = np.sqrt(((tr[0] - br[0]) ** 2) + ((tr[1] - br[1]) ** 2))
heightB = np.sqrt(((tl[0] - bl[0]) ** 2) + ((tl[1] - bl[1]) ** 2))
maxHeight = max(int(heightA), int(heightB))
print(f"max width{maxWidth} and max height = {maxHeight}")
# now that we have the dimensions of the new image, construct
# the set of destination points to obtain a "birds eye view",
# (i.e. top-down view) of the image, again specifying points
# in the top-left, top-right, bottom-right, and bottom-left
# order
dst = np.array([
[0, 0],
[maxWidth - 1, 0],
[maxWidth - 1, maxHeight - 1],
[0, maxHeight - 1]], dtype = "float32")
print(dst)
# Out:
# max width399 and max height = 393
# [[  0.   0.]
#  [398.   0.]
#  [398. 392.]
#  [  0. 392.]]

# %%
M = cv.getPerspectiveTransform(rect, dst)
warped = cv.warpPerspective(orig, M, (maxWidth, maxHeight))

# %%
plt.imshow(warped)
plt.show()

# %%
gray =  warped

# %%
ret2,thresh2 = cv.threshold(gray,109,255,cv.THRESH_BINARY)

# %%
plt.imshow(thresh2)
plt.show()

# %%
image = cv.copyMakeBorder(thresh2,5,5,5,5, cv.BORDER_CONSTANT,value=[0,0,0])

# %%
plt.imshow(image)
cv.imwrite("borderjupyert.jpg",image)
plt.show()
jincrement = image.shape[0]//10
iincrement = image.shape[1]//10

# %%
#for i in range(0,400,40):
for i in range(0,image.shape[1],iincrement):
    for j in range(0,image.shape[0],jincrement):
        
        
        image = cv.rectangle(image,(j,i),(j+10,i+15),[255,255,255],-1)

# %%
plt.imshow(image)
plt.show()
