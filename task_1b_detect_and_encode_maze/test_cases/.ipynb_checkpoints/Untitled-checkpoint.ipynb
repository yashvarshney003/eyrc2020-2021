# %%
import cv2 as cv
import numpy as np 
from matplotlib import pyplot as plt
import imutils

# %%
image = cv.imread("maze09.jpg",1)
orig = image.copy()

# %%
ratio = image.shape[0] / 500.0

# %%
image
# Out:
# array([[[104, 109, 110],
#         [106, 111, 112],
#         [111, 116, 117],
#         ...,
#         [101, 110, 114],
#         [ 98, 107, 111],
#         [ 96, 105, 109]],
#
#        [[106, 111, 112],
#         [108, 113, 114],
#         [112, 117, 118],
#         ...,
#         [ 94, 103, 107],
#         [ 96, 105, 109],
#         [ 99, 108, 112]],
#
#        [[107, 112, 113],
#         [108, 113, 114],
#         [111, 116, 117],
#         ...,
#         [ 93, 102, 106],
#         [ 99, 108, 112],
#         [105, 114, 118]],
#
#        ...,
#
#        [[147, 150, 155],
#         [148, 151, 156],
#         [149, 152, 157],
#         ...,
#         [172, 172, 178],
#         [173, 173, 179],
#         [169, 169, 175]],
#
#        [[149, 152, 157],
#         [147, 150, 155],
#         [147, 150, 155],
#         ...,
#         [173, 173, 179],
#         [173, 173, 179],
#         [169, 169, 175]],
#
#        [[149, 152, 157],
#         [146, 149, 154],
#         [144, 147, 152],
#         ...,
#         [172, 172, 178],
#         [173, 173, 179],
#         [168, 168, 174]]], dtype=uint8)

# %%
plt.imshow(image)
plt.show()

# %%
gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)

# %%
gray = cv.GaussianBlur(gray, (3,3), 2)
plt.imshow(gray)
imgplot1 = plt.imshow(gray, cmap='gray')

# %%
edged = cv.Canny(gray, 30, 200)

plt.imshow(edged)
imgplot = plt.imshow(edged, cmap='gray')

# %%
cnts = cv.findContours(edged.copy(), cv.RETR_LIST, cv.CHAIN_APPROX_SIMPLE)
cnts
# Out:
# ([array([[[272,  49]],
#
#          [[273,  48]],
#
#          [[275,  48]],
#
#          ...,
#
#          [[228,  85]],
#
#          [[228,  51]],
#
#          [[230,  49]]], dtype=int32),
#   array([[[273,  48]],
#
#          [[272,  49]],
#
#          [[229,  49]],
#
#          ...,
#
#          [[288,  49]],
#
#          [[276,  49]],
#
#          [[275,  48]]], dtype=int32),
#   array([[[213,  46]],
#
#          [[214,  45]],
#
#          [[387,  45]],
#
#          [[388,  46]],
#
#          [[391,  46]],
#
#          [[392,  45]],
#
#          [[396,  45]],
#
#          [[397,  46]],
#
#          [[434,  46]],
#
#          [[435,  47]],
#
#          [[460,  47]],
#
#          [[461,  48]],
#
#          [[462,  48]],
#
#          [[463,  49]],
#
#          [[463,  65]],
#
#          [[464,  66]],
#
#          [[464,  95]],
#
#          [[465,  96]],
#
#          [[465, 127]],
#
#          [[466, 128]],
#
#          [[466, 163]],
#
#          [[467, 164]],
#
#          [[467, 197]],
#
#          [[468, 198]],
#
#          [[468, 235]],
#
#          [[469, 236]],
#
#          [[469, 275]],
#
#          [[470, 276]],
#
#          [[470, 320]],
#
#          [[471, 321]],
#
#          [[471, 379]],
#
#          [[472, 380]],
#
#          [[472, 447]],
#
#          [[471, 448]],
#
#          [[470, 448]],
#
#          [[469, 449]],
#
#          [[447, 449]],
#
#          [[446, 450]],
#
#          [[420, 450]],
#
#          [[419, 451]],
#
#          [[394, 451]],
#
#          [[393, 452]],
#
#          [[359, 452]],
#
#          [[358, 453]],
#
#          [[322, 453]],
#
#          [[321, 454]],
#
#          [[274, 454]],
#
#          [[273, 455]],
#
#          [[201, 455]],
#
#          [[200, 456]],
#
#          [[192, 456]],
#
#          [[191, 455]],
#
#          [[182, 455]],
#
#          [[181, 456]],
#
#          [[ 93, 456]],
#
#          [[ 92, 457]],
#
#          [[ 64, 457]],
#
#          [[ 63, 456]],
#
#          [[ 62, 456]],
#
#          [[ 61, 455]],
#
#          [[ 61, 396]],
#
#          [[ 60, 395]],
#
#          [[ 60, 394]],
#
#          [[ 61, 393]],
#
#          [[ 61, 389]],
#
#          [[ 60, 388]],
#
#          [[ 60, 222]],
#
#          [[ 59, 221]],
#
#          [[ 60, 220]],
#
#          [[ 60,  78]],
#
#          [[ 61,  77]],
#
#          [[ 61,  50]],
#
#          [[ 63,  48]],
#
#          [[ 69,  48]],
#
#          [[ 70,  47]],
#
#          [[ 72,  47]],
#
#          [[ 73,  48]],
#
#          [[ 74,  48]],
#
#          [[ 75,  47]],
#
#          [[152,  47]],
#
#          [[153,  46]]], dtype=int32),
#   array([[[214,  45]],
#
#          [[213,  46]],
#
#          [[153,  46]],
#
#          [[152,  47]],
#
#          [[ 75,  47]],
#
#          [[ 74,  48]],
#
#          [[ 73,  48]],
#
#          [[ 72,  47]],
#
#          [[ 70,  47]],
#
#          [[ 69,  48]],
#
#          [[ 62,  48]],
#
#          [[ 61,  49]],
#
#          [[ 61,  77]],
#
#          [[ 60,  78]],
#
#          [[ 60, 220]],
#
#          [[ 59, 221]],
#
#          [[ 60, 222]],
#
#          [[ 60, 388]],
#
#          [[ 61, 389]],
#
#          [[ 61, 393]],
#
#          [[ 60, 394]],
#
#          [[ 60, 395]],
#
#          [[ 61, 396]],
#
#          [[ 61, 455]],
#
#          [[ 62, 456]],
#
#          [[ 63, 456]],
#
#          [[ 64, 457]],
#
#          [[ 92, 457]],
#
#          [[ 93, 456]],
#
#          [[181, 456]],
#
#          [[182, 455]],
#
#          [[191, 455]],
#
#          [[192, 456]],
#
#          [[200, 456]],
#
#          [[201, 455]],
#
#          [[273, 455]],
#
#          [[274, 454]],
#
#          [[321, 454]],
#
#          [[322, 453]],
#
#          [[358, 453]],
#
#          [[359, 452]],
#
#          [[393, 452]],
#
#          [[394, 451]],
#
#          [[419, 451]],
#
#          [[420, 450]],
#
#          [[446, 450]],
#
#          [[447, 449]],
#
#          [[469, 449]],
#
#          [[470, 448]],
#
#          [[472, 448]],
#
#          [[472, 380]],
#
#          [[471, 379]],
#
#          [[471, 321]],
#
#          [[470, 320]],
#
#          [[470, 276]],
#
#          [[469, 275]],
#
#          [[469, 236]],
#
#          [[468, 235]],
#
#          [[468, 198]],
#
#          [[467, 197]],
#
#          [[467, 164]],
#
#          [[466, 163]],
#
#          [[466, 128]],
#
#          [[465, 127]],
#
#          [[465,  96]],
#
#          [[464,  95]],
#
#          [[464,  66]],
#
#          [[463,  65]],
#
#          [[463,  48]],
#
#          [[461,  48]],
#
#          [[460,  47]],
#
#          [[435,  47]],
#
#          [[434,  46]],
#
#          [[397,  46]],
#
#          [[396,  45]],
#
#          [[392,  45]],
#
#          [[391,  46]],
#
#          [[388,  46]],
#
#          [[387,  45]]], dtype=int32)],
#  array([[[ 1, -1, -1, -1],
#          [ 2,  0, -1, -1],
#          [ 3,  1, -1, -1],
#          [-1,  2, -1, -1]]], dtype=int32))

# %%
cnts = imutils.grab_contours(cnts)
cnts
# Out:
# [array([[[272,  49]],
#
#         [[273,  48]],
#
#         [[275,  48]],
#
#         ...,
#
#         [[228,  85]],
#
#         [[228,  51]],
#
#         [[230,  49]]], dtype=int32),
#  array([[[273,  48]],
#
#         [[272,  49]],
#
#         [[229,  49]],
#
#         ...,
#
#         [[288,  49]],
#
#         [[276,  49]],
#
#         [[275,  48]]], dtype=int32),
#  array([[[213,  46]],
#
#         [[214,  45]],
#
#         [[387,  45]],
#
#         [[388,  46]],
#
#         [[391,  46]],
#
#         [[392,  45]],
#
#         [[396,  45]],
#
#         [[397,  46]],
#
#         [[434,  46]],
#
#         [[435,  47]],
#
#         [[460,  47]],
#
#         [[461,  48]],
#
#         [[462,  48]],
#
#         [[463,  49]],
#
#         [[463,  65]],
#
#         [[464,  66]],
#
#         [[464,  95]],
#
#         [[465,  96]],
#
#         [[465, 127]],
#
#         [[466, 128]],
#
#         [[466, 163]],
#
#         [[467, 164]],
#
#         [[467, 197]],
#
#         [[468, 198]],
#
#         [[468, 235]],
#
#         [[469, 236]],
#
#         [[469, 275]],
#
#         [[470, 276]],
#
#         [[470, 320]],
#
#         [[471, 321]],
#
#         [[471, 379]],
#
#         [[472, 380]],
#
#         [[472, 447]],
#
#         [[471, 448]],
#
#         [[470, 448]],
#
#         [[469, 449]],
#
#         [[447, 449]],
#
#         [[446, 450]],
#
#         [[420, 450]],
#
#         [[419, 451]],
#
#         [[394, 451]],
#
#         [[393, 452]],
#
#         [[359, 452]],
#
#         [[358, 453]],
#
#         [[322, 453]],
#
#         [[321, 454]],
#
#         [[274, 454]],
#
#         [[273, 455]],
#
#         [[201, 455]],
#
#         [[200, 456]],
#
#         [[192, 456]],
#
#         [[191, 455]],
#
#         [[182, 455]],
#
#         [[181, 456]],
#
#         [[ 93, 456]],
#
#         [[ 92, 457]],
#
#         [[ 64, 457]],
#
#         [[ 63, 456]],
#
#         [[ 62, 456]],
#
#         [[ 61, 455]],
#
#         [[ 61, 396]],
#
#         [[ 60, 395]],
#
#         [[ 60, 394]],
#
#         [[ 61, 393]],
#
#         [[ 61, 389]],
#
#         [[ 60, 388]],
#
#         [[ 60, 222]],
#
#         [[ 59, 221]],
#
#         [[ 60, 220]],
#
#         [[ 60,  78]],
#
#         [[ 61,  77]],
#
#         [[ 61,  50]],
#
#         [[ 63,  48]],
#
#         [[ 69,  48]],
#
#         [[ 70,  47]],
#
#         [[ 72,  47]],
#
#         [[ 73,  48]],
#
#         [[ 74,  48]],
#
#         [[ 75,  47]],
#
#         [[152,  47]],
#
#         [[153,  46]]], dtype=int32),
#  array([[[214,  45]],
#
#         [[213,  46]],
#
#         [[153,  46]],
#
#         [[152,  47]],
#
#         [[ 75,  47]],
#
#         [[ 74,  48]],
#
#         [[ 73,  48]],
#
#         [[ 72,  47]],
#
#         [[ 70,  47]],
#
#         [[ 69,  48]],
#
#         [[ 62,  48]],
#
#         [[ 61,  49]],
#
#         [[ 61,  77]],
#
#         [[ 60,  78]],
#
#         [[ 60, 220]],
#
#         [[ 59, 221]],
#
#         [[ 60, 222]],
#
#         [[ 60, 388]],
#
#         [[ 61, 389]],
#
#         [[ 61, 393]],
#
#         [[ 60, 394]],
#
#         [[ 60, 395]],
#
#         [[ 61, 396]],
#
#         [[ 61, 455]],
#
#         [[ 62, 456]],
#
#         [[ 63, 456]],
#
#         [[ 64, 457]],
#
#         [[ 92, 457]],
#
#         [[ 93, 456]],
#
#         [[181, 456]],
#
#         [[182, 455]],
#
#         [[191, 455]],
#
#         [[192, 456]],
#
#         [[200, 456]],
#
#         [[201, 455]],
#
#         [[273, 455]],
#
#         [[274, 454]],
#
#         [[321, 454]],
#
#         [[322, 453]],
#
#         [[358, 453]],
#
#         [[359, 452]],
#
#         [[393, 452]],
#
#         [[394, 451]],
#
#         [[419, 451]],
#
#         [[420, 450]],
#
#         [[446, 450]],
#
#         [[447, 449]],
#
#         [[469, 449]],
#
#         [[470, 448]],
#
#         [[472, 448]],
#
#         [[472, 380]],
#
#         [[471, 379]],
#
#         [[471, 321]],
#
#         [[470, 320]],
#
#         [[470, 276]],
#
#         [[469, 275]],
#
#         [[469, 236]],
#
#         [[468, 235]],
#
#         [[468, 198]],
#
#         [[467, 197]],
#
#         [[467, 164]],
#
#         [[466, 163]],
#
#         [[466, 128]],
#
#         [[465, 127]],
#
#         [[465,  96]],
#
#         [[464,  95]],
#
#         [[464,  66]],
#
#         [[463,  65]],
#
#         [[463,  48]],
#
#         [[461,  48]],
#
#         [[460,  47]],
#
#         [[435,  47]],
#
#         [[434,  46]],
#
#         [[397,  46]],
#
#         [[396,  45]],
#
#         [[392,  45]],
#
#         [[391,  46]],
#
#         [[388,  46]],
#
#         [[387,  45]]], dtype=int32)]

# %%
cnts = sorted(cnts, key = cv.contourArea, reverse = True)
# loop over the contours

	# show the contour (outline) of the piece of paper

# %%
len1 = len(cnts)
len1
# Out:
# 4

# %%
for c in cnts:
# approximate the contour
    peri = cv.arcLength(c, True)
    approx = cv.approxPolyDP(c, 0.02 * peri, True)
    print(len(approx))
# if our approximated contour has four points, then we
# can assume that we have found our screen
    if len(approx) == 4:
        screenCnt = approx
        break
# Out:
# 4

# %%
print("STEP 2: Find contours of paper")
print(screenCnt)
cv.drawContours(image, [screenCnt], -1, (0, 255, 0), 2)
# Out:
# STEP 2: Find contours of paper
# [[[ 61  49]]
#
#  [[ 62 456]]
#
#  [[472 448]]
#
#  [[463  48]]]
# array([[[104, 109, 110],
#         [106, 111, 112],
#         [111, 116, 117],
#         ...,
#         [101, 110, 114],
#         [ 98, 107, 111],
#         [ 96, 105, 109]],
#
#        [[106, 111, 112],
#         [108, 113, 114],
#         [112, 117, 118],
#         ...,
#         [ 94, 103, 107],
#         [ 96, 105, 109],
#         [ 99, 108, 112]],
#
#        [[107, 112, 113],
#         [108, 113, 114],
#         [111, 116, 117],
#         ...,
#         [ 93, 102, 106],
#         [ 99, 108, 112],
#         [105, 114, 118]],
#
#        ...,
#
#        [[147, 150, 155],
#         [148, 151, 156],
#         [149, 152, 157],
#         ...,
#         [172, 172, 178],
#         [173, 173, 179],
#         [169, 169, 175]],
#
#        [[149, 152, 157],
#         [147, 150, 155],
#         [147, 150, 155],
#         ...,
#         [173, 173, 179],
#         [173, 173, 179],
#         [169, 169, 175]],
#
#        [[149, 152, 157],
#         [146, 149, 154],
#         [144, 147, 152],
#         ...,
#         [172, 172, 178],
#         [173, 173, 179],
#         [168, 168, 174]]], dtype=uint8)

# %%
plt.imshow(image)
plt.show()

# %%
pts = screenCnt.reshape(4, 2)
print(pts)
# Out:
# [[ 61  49]
#  [ 62 456]
#  [472 448]
#  [463  48]]

# %%
rect = np.zeros((4, 2), dtype = "float32")
# the top-left point will have the smallest sum, whereas
# the bottom-right point will have the largest sum
s = pts.sum(axis = 1)
rect[0] = pts[np.argmin(s)]
rect[2] = pts[np.argmax(s)]
# now, compute the difference between the points, the
# top-right point will have the smallest difference,
# whereas the bottom-left will have the largest difference
diff = np.diff(pts, axis = 1)
rect[1] = pts[np.argmin(diff)]
rect[3] = pts[np.argmax(diff)]
# return the ordered coordinates
print(rect)
# Out:
# [[ 61.  49.]
#  [463.  48.]
#  [472. 448.]
#  [ 62. 456.]]

# %%
(tl, tr, br, bl) = rect
# compute the width of the new image, which will be the
# maximum distance between bottom-right and bottom-left
# x-coordiates or the top-right and top-left x-coordinates
widthA = np.sqrt(((br[0] - bl[0]) ** 2) + ((br[1] - bl[1]) ** 2))
widthB = np.sqrt(((tr[0] - tl[0]) ** 2) + ((tr[1] - tl[1]) ** 2))
maxWidth = max(int(widthA), int(widthB))
# compute the height of the new image, which will be the
# maximum distance between the top-right and bottom-right
# y-coordinates or the top-left and bottom-left y-coordinates
heightA = np.sqrt(((tr[0] - br[0]) ** 2) + ((tr[1] - br[1]) ** 2))
heightB = np.sqrt(((tl[0] - bl[0]) ** 2) + ((tl[1] - bl[1]) ** 2))
maxHeight = max(int(heightA), int(heightB))
print(f"max width{maxWidth} and max height = {maxHeight}")
# now that we have the dimensions of the new image, construct
# the set of destination points to obtain a "birds eye view",
# (i.e. top-down view) of the image, again specifying points
# in the top-left, top-right, bottom-right, and bottom-left
# order
dst = np.array([
[0, 0],
[maxWidth - 1, 0],
[maxWidth - 1, maxHeight - 1],
[0, maxHeight - 1]], dtype = "float32")
print(dst)
# Out:
# max width410 and max height = 407
# [[  0.   0.]
#  [409.   0.]
#  [409. 406.]
#  [  0. 406.]]

# %%
M = cv.getPerspectiveTransform(rect, dst)
warped = cv.warpPerspective(orig, M, (maxWidth, maxHeight))

# %%
plt.imshow(warped)
plt.show()

# %%
gray =  warped
gray = cv.cvtColor(gray, cv.COLOR_BGR2GRAY)
gray.shape
#gray = cv.GaussianBlur(gray,(5,5),0)
# Out:
# (407, 410)

# %%
ret2,thresh2 = cv.threshold(gray,100,255,cv.THRESH_BINARY)

# changes can be done

# %%
plt.imshow(thresh2,cmap= 'gray')
plt.show()

# %%
thresh = cv.copyMakeBorder(thresh2,5,5,5,5, cv.BORDER_CONSTANT,value=[0,0,0]) 
ret2,thresh = cv.threshold(thresh,100,255,cv.THRESH_BINARY)

print(thresh.shape)
resized_image = cv.resize(thresh, (400, 400)) 
resized_image.shape
# Out:
# (417, 420)
# (400, 400)

# %%
plt.imshow(resized_image)
cv.imwrite("borderjupyert.jpg",resized_image)
plt.show()
jincrement = resized_image.shape[0]//10
iincrement = resized_image.shape[1]//10
print(jincrement)
print(iincrement)
# Out:
# 40
# 40

# %%
#for i in range(0,400,40):
#for i in range(0,resized_image.shape[1],iincrement):
i=0 
array = []
ret2,resized_image = cv.threshold(resized_image,100,255,cv.THRESH_BINARY_INV)
array.append([])
for j in range(0,resized_image.shape[0],jincrement):
        img_temp =0
       
        print(f"{j//40}-------------------------------------------------------------------")
        img_temp = resized_image[i:i+44,j:j+44]
       
        plt.imshow(resized_image,cmap= 'gray')
        plt.show()
        
        ret2,img_temp = cv.threshold(img_temp,100,255,cv.THRESH_BINARY)

        
        size = 40
        print(i,j)
        print(img_temp[20,5])
        
        
        img_temp = cv.rectangle(img_temp,(0,0),(10,10),[255,255,255],-1)
        img_temp = cv.rectangle(img_temp,(35,0),(44,10),[255,255,255],-1)

        img_temp = cv.rectangle(img_temp,(0,35),(10,45),[255,255,255],-1)

        img_temp = cv.rectangle(img_temp,(35,35),(44,44),[255,255,255],-1)
        north = 0
        west = 0
        east = 0
        south = 0
        print("outside if")
        print(img_temp[20,0],img_temp[20,5],img_temp[20,10])
        print(bool(img_temp[20,0]),bool(img_temp[20,5]),bool(img_temp[20,10]))
        print(bool(img_temp[20,0]) or bool(img_temp[20,5]) or bool(img_temp[20,10]))
        if(bool(img_temp[20,0]) or bool(img_temp[20,5]) or bool(img_temp[20,10])):
                
                north = 2
                print(f"north {up}")
        if(bool(img_temp[0,20]) or bool(img_temp[10,20]) or bool(img_temp[15,20])):
                west = 1
                print(f" west {west}")
        if(bool(img_temp[20,30]) or bool(img_temp[20,35]) or bool(img_temp[20,40]) ):
                
                south = 8
                print(f" south {south}")
        if(bool(img_temp[30,20]) or bool(img_temp[35,20]) or bool(img_temp[40,20]) ):
                
                east = 4
                print(f" east {east}")
        array[0].append(north + south + east + west)
        plt.imshow(img_temp,cmap= 'gray')
        plt.show()
        print(array)
# Out:
# 0-------------------------------------------------------------------
# 0 0
# 0
# outside if
# 0 0 255
# False False True
# True
# north 2
#  west 1
#  south 8
#  east 4
# [[15]]
# 1-------------------------------------------------------------------
# 0 40
# 0
# outside if
# 0 0 0
# False False False
# False
#  west 1
# [[15, 1]]
# 2-------------------------------------------------------------------
# 0 80
# 255
# outside if
# 255 255 255
# True True True
# True
# north 2
#  west 1
#  south 8
#  east 4
# [[15, 1, 15]]
# 3-------------------------------------------------------------------
# 0 120
# 0
# outside if
# 0 0 0
# False False False
# False
#  west 1
#  south 8
#  east 4
# [[15, 1, 15, 13]]
# 4-------------------------------------------------------------------
# 0 160
# 0
# outside if
# 0 0 255
# False False True
# True
# north 2
#  west 1
#  south 8
#  east 4
# [[15, 1, 15, 13, 15]]
# 5-------------------------------------------------------------------
# 0 200
# 0
# outside if
# 0 0 0
# False False False
# False
#  west 1
#  east 4
# [[15, 1, 15, 13, 15, 5]]
# 6-------------------------------------------------------------------
# 0 240
# 255
# outside if
# 255 255 255
# True True True
# True
# north 2
#  west 1
#  south 8
#  east 4
# [[15, 1, 15, 13, 15, 5, 15]]
# 7-------------------------------------------------------------------
# 0 280
# 0
# outside if
# 0 0 0
# False False False
# False
#  west 1
#  south 8
# [[15, 1, 15, 13, 15, 5, 15, 9]]
# 8-------------------------------------------------------------------
# 0 320
# 255
# outside if
# 0 255 255
# False True True
# True
# north 2
#  west 1
#  south 8
#  east 4
# [[15, 1, 15, 13, 15, 5, 15, 9, 15]]
# 9-------------------------------------------------------------------
# 0 360
# 0
# outside if
# 0 0 0
# False False False
# False
#  west 1
#  south 8
# [[15, 1, 15, 13, 15, 5, 15, 9, 15, 9]]

# %%
[3, 2, 10, 14, 3, 10, 10, 6, 11, 6]
